# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# 1.Seaborn_Mathplotlib_Homework
# https://www.kaggle.com/datasets web sitesinden Data seciniz ve verinin hikayesini oluşturunuz.
#
# 2.Eksik verilerde gozelm analizi yapın (NaN vakues). Doldurulmasi gerekeni gerekli yöntem ile doldurun.
#
# 3.Dagilim Grafikleri çizdiriniz: • Bar plot (çaprazlama grafikleri dahil) çizdiriniz • Box plot (çaprazlama grafikleri dahil) çizdiriniz • Histogram yogunluk Grafikleri (çaprazlama grafikleri dahil) çizdiriniz • Violin grafikleri (çaprazlama grafikleri dahil) çizdiriniz
#
# 4-Korelasyon Grafikleri çizdiriniz: • Scatter plot(çaprazlama grafikleri dahil) çizdiriniz • Scatter plot matrisi çizdiriniz • Heatmap grafigi çizdiriniz • Çizgi grafik(çaprazlama grafikleri dahil) çizdiriniz • Basit zaman serisi Grafigi çizdiriniz 5. Odevi Kaggle da yapip linki GitHub'yükleyiniz.

# %% [markdown]
# # Veri Seti Hikayesi
#
# * Bu veri kümesi, UEFA Şampiyonlar Ligi 2021-22 sezonunun tüm oyuncu istatistiklerini içerir.
#
# * player_name : oyuncu isimleri
# * club: takım isimleri
# * position: oyunucunun oynadığı mevki
# * goals: gol sayıları
# * right_foot:sağ ayakla attığı gol
# * left_foot: sol ayakla attığı gol
# * headers : kafa golü
# * others: diğer türlü gol
# * inside_area :ce sahası içinden
# * outside_areas:cezasahası dışından
# * penalties: penaltıdan atılan gol
# * match_played:oynadığı maç
#
#
# * Herhangi bir takımın zayıf noktalarını keşfedin.
# * Performans analizine dayanarak oyuncuların satılması gerektiğini önerin.
# * Sezonun Oyuncusu Adayını belirleyin

# %%
data = pd.read_csv(r"/kaggle/input/ucl-202122-uefa-champions-league/goals.csv")
df = data.copy()
df.head()

# %%
df.tail()

# %%
#methodun tamamında veri var eksik veri yok 
df.info()

# %%
df.dtypes

# %%
df.shape

# %%
df.columns

# %%
df.describe().T

# %%
df.describe(include="all").T

# %%
df.isnull().sum()

# %%
unique = pd.DataFrame(df.nunique(), columns=['nunique'])
unique

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
df.value_counts

# %%
df

# %%
df.player_name.unique()

# %%
df["player_name"].value_counts().count()

# %% [markdown]
# 3.Dagilim Grafikleri çizdiriniz: • Bar plot (çaprazlama grafikleri dahil) çizdiriniz • Box plot (çaprazlama grafikleri dahil) çizdiriniz • Histogram yogunluk Grafikleri (çaprazlama grafikleri dahil) çizdiriniz • Violin grafikleri (çaprazlama grafikleri dahil) çizdiriniz

# %%
df

# %%
df["position"].value_counts().plot.barh()

# %%
df_numeric = df.select_dtypes(include=["int64","float64"])

# %%
df_numeric

# %%
df_numeric.describe().T

# %%
import seaborn as sns

# %%
df

# %%
#sns.barplot(x="goals", y=df_numeric.goals.index, data=df)
sns.catplot(x="right_foot",y ="goals", data=df)

# %%
sns.catplot(x="left_foot",y ="goals", data=df)

# %%
sns.barplot(x="position",y ="goals",hue = "inside_area",  data=df)

# %%
#
sns.barplot(x="position",y ="goals",hue = "outside_areas",  data=df)

# %%
#histogram 
#displot da kullanılır
sns.distplot(df.goals,kde=False)

# %%
df.goals.describe().T

# %%
sns.distplot(df.goals,kde=True)

# %%
sns.distplot(df.goals, bins =5 ,kde=False)

# %%
#sns.kdeplot(df.goals,shade=True)
sns.kdeplot(df.goals,shade=True , color="r")

# %%
sns.catplot(x="position",y="goals",hue="match_played",kind="point",data=df)

# %%
sns.boxplot(x=df["goals"])
#sns.boxplot(y=df["goals"])

# %%
df.describe().T

# %%
#boxplot çaprazlama 
sns.boxplot(x="match_played",y="goals", data=df )

# %%
sns.boxplot(x="right_foot",y="goals", data=df )

# %%
sns.boxplot(x="left_foot",y="goals", data=df )

# %%
sns.boxplot(x="headers",y="goals", data=df )

# %%
df

# %%
df.club.value_counts()

# %%
sns.boxplot(x="match_played",y = "goals",hue="inside_area",data=df)

# %%
sns.boxplot(x="goals",y = "penalties",hue="match_played",data=df)

# %% [markdown]
# violin

# %%
sns.catplot(y="goals",kind="violin",data=df)

# %%
sns.violinplot(y="goals",data=df)

# %% [markdown]
# çapraz çizim

# %%
sns.catplot(x ="position",y="goals",kind="violin",data=df)

# %%
sns.violinplot(x ="position",y="goals",data=df)

# %%
sns.violinplot(x ="position",y="goals",hue="match_played",data=df)

# %% [markdown]
# # scatterplot

# %%
sns.scatterplot(x="goals",y="match_played",data=df)

# %%
sns.scatterplot(x="goals",y="position",data=df)

# %%
sns.scatterplot(x="goals",y="match_played",hue="position",style="position",data=df)
#sns.scatterplot(x="goals",y="match_played",hue="position",data=df)
#sns.scatterplot(x="goals",y="match_played",hue="position",size="position",data=df)

# %%
sns.scatterplot(x="goals",y="match_played",hue="club",size="club",data=df)

# %%
import matplotlib.pyplot as plt
sns.lmplot(x="goals",y="match_played",data=df)

# %%
sns.lmplot(x="goals",y="right_foot",hue="left_foot",data=df)

# %%
sns.lmplot(x="goals",y="match_played",hue="position",col="penalties",row ="headers",data=df)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue ="position")

# %% [markdown]
# # heatmap

# %%
df

# %%
df_numeric = df.select_dtypes(include=["int64","float64"])

# %%
sns.heatmap(df_numeric)

# %%
sns.heatmap(df_numeric, annot=True, fmt="d")

# %% [markdown]
# # Çizgi Grafikleri

# %%
df

# %%
df.groupby("match_played")["goals"].count()

# %%
df.groupby("match_played")["goals"].describe()

# %%
sns.lineplot(x="match_played",y="goals",data=df)

# %%
#çaprazlama 
sns.lineplot(x="match_played",y="goals",hue ="position",data=df)

# %% [markdown]
# # basit zaman serisi grafikleri

# %%
# !pip install pandas_datareader

# %%
import pandas_datareader.data as gdp
import datetime

# %% [markdown]
# * Econdb , 90'dan fazla resmi istatistik kurumundan ekonomik veriler sağlar. Ücretsiz API, veri kümelerinde toplanan zaman serilerinin eksiksiz Econdb veritabanına erişim sağlar.

# %%
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2013, 1, 27)
gdp = web.DataReader('GDP', 'fred', start, end)
#df = web.DataReader('ticker=RGDPUS', 'econdb')  açıklamanın kodu
#df = web.DataReader(["USD/JPY", "BTC/CNY"], "av-forex",api_key=os.getenv('ALPHAVANTAGE_API_KEY'))

# %%
gdp

# %%
gdp.shape

# %%
gdp.describe().T

# %%
gdp.head()

# %%
a =  gdp["GDP"]

# %%
a.head()

# %%
a.plot()

# %%
a.index
